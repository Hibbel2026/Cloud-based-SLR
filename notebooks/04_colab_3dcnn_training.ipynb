# %% [markdown]
# # 3D CNN Sign Language Recognition - Colab Training
#
# Train 3D CNN on raw video frames using GPU

# %%
import torch
print(f"GPU: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

# %%
# !git clone https://github.com/Hibbel2026/Cloud-based-SLR.git
# %cd Cloud-based-SLR

# %%
# !pip install opencv-python torch torchvision tqdm -q

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r /content/drive/MyDrive/WLASL_100 ./data/

# %%
# !python3 src/train_3dcnn.py --model 3dcnn --data_dir data/WLASL_100 --batch_size 8 --num_frames 16 --device cuda

# %%
# !git config --global user.email 'email@example.com'
# !git config --global user.name 'Name'
# !git add checkpoints/
# !git commit -m 'Add 3D CNN model'
# !git push origin Baseline-ML
